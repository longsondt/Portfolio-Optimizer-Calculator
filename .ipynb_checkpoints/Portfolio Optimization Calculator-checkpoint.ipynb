# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import datetime as datetime

# %% [markdown]
# # Step 1. Setting up the necessary information

# %%
avaliable_fund = int(input('How much will you invest in this portfolio? '))
number_of_securities = int(input('How many securities will you have in this portfolio? '))

securities = []
for number in range(number_of_securities):
    securities.append(input(f'Please type in security {number+1}: ').upper())
securities
# Out:
# How much will you invest in this portfolio? 1
# How many securities will you have in this portfolio? 2
# Please type in security 1: ko
# Please type in security 2: fb
# ['KO', 'FB']

# %%
print('Please enter a start date')
# Out:
# Please enter a start date

# %%
start_year = int(input('Please enter a start year: '))
start_month = int(input('Please enter a start month: '))
start_day = int(input('Please enter a start date: '))
start_date = datetime.date(start_year, start_month, start_day)
start_date
# Out:
# Please enter a start year: 2001
# Please enter a start month: 2
# Please enter a start date: 23
# datetime.date(2001, 2, 23)

# %%
print('Please enter a end date')
# Out:
# Please enter a end date

# %%
end_year = int(input('Please enter a end year: '))
end_month = int(input('Please enter a end month: '))
end_day = int(input('Please enter a end date: '))
end_date = datetime.date(end_year, end_month, end_day)
end_date
# Out:
# Please enter a end year: 2021
# Please enter a end month: 12
# Please enter a end date: 7
# datetime.date(2021, 12, 7)

# %%
df = pd.DataFrame()

for security in securities:
    df[security] = web.DataReader(security, data_source='yahoo', start = start_date, end = end_date)['Adj Close']

df
# Out:
#                    KO          FB
# Date
# 2001-02-22  14.714545         NaN
# 2001-02-23  14.439632         NaN
# 2001-02-26  14.570147         NaN
# 2001-02-27  14.439632         NaN
# 2001-02-28  14.725657         NaN
# ...               ...         ...
# 2021-11-30  52.450001  324.459991
# 2021-12-01  52.299999  310.600006
# 2021-12-02  53.070000  310.390015
# 2021-12-03  53.540001  306.839996
# 2021-12-06  54.910000  317.869995
#
# [5231 rows x 2 columns]

# %%
pct_change = df.pct_change()
list(pct_change['FB'])
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...
